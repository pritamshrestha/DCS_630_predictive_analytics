# %%
# load required libraries
library(stats)
library(dplyr)
# Out:
# Attaching package: 'dplyr'
#
# The following objects are masked from 'package:stats':
#
#     filter, lag
#
# The following objects are masked from 'package:base':
#
#     intersect, setdiff, setequal, union

# %%
# loading datasets
train<-read.csv('train.csv',nrows=10000)
summary(train)
# Out:
#                date_time      site_name      posa_continent
#  2014-06-28 08:30:48:   3   Min.   : 2.000   Min.   :0.000
#  2013-09-04 12:15:25:   2   1st Qu.: 2.000   1st Qu.:3.000
#  2014-07-07 02:07:44:   2   Median : 2.000   Median :3.000
#  2014-12-17 17:48:13:   2   Mean   : 8.261   Mean   :2.744
#  2014-12-25 15:21:10:   2   3rd Qu.:11.000   3rd Qu.:3.000
#  2013-01-07 10:17:08:   1   Max.   :47.000   Max.   :4.000
#  (Other)            :9988
#  user_location_country user_location_region user_location_city
#  Min.   :  0.00        Min.   :   0.0       Min.   :    3
#  1st Qu.: 66.00        1st Qu.: 172.0       1st Qu.: 9876
#  Median : 66.00        Median : 258.0       Median :25954
#  Mean   : 85.71        Mean   : 272.6       Mean   :26942
#  3rd Qu.: 69.00        3rd Qu.: 354.0       3rd Qu.:43175
#  Max.   :239.00        Max.   :1003.0       Max.   :56451
#
#  orig_destination_distance    user_id        is_mobile        is_package
# ...

# %%
destination<-read.csv('destinations.csv',nrows=100000)
summary(destination)
# Out:
#  srch_destination_id       d1               d2               d3
#  Min.   :    0       Min.   :-2.598   Min.   :-2.672   Min.   :-2.672
#  1st Qu.:16320       1st Qu.:-2.209   1st Qu.:-2.220   1st Qu.:-2.224
#  Median :32278       Median :-2.186   Median :-2.193   Median :-2.195
#  Mean   :32359       Mean   :-2.194   Mean   :-2.203   Mean   :-2.207
#  3rd Qu.:48468       3rd Qu.:-2.175   3rd Qu.:-2.179   3rd Qu.:-2.180
#  Max.   :64993       Max.   :-1.596   Max.   :-1.341   Max.   :-1.918
#        d4               d5               d6               d7
#  Min.   :-2.672   Min.   :-2.672   Min.   :-2.344   Min.   :-2.672
#  1st Qu.:-2.211   1st Qu.:-2.192   1st Qu.:-2.154   1st Qu.:-2.219
#  Median :-2.188   Median :-2.178   Median :-2.089   Median :-2.193
#  Mean   :-2.194   Mean   :-2.161   Mean   :-2.045   Mean   :-2.202
#  3rd Qu.:-2.177   3rd Qu.:-2.153   3rd Qu.:-1.976   3rd Qu.:-2.179
#  Max.   :-1.815   Max.   :-1.608   Max.   :-1.209   Max.   :-1.474
# ...

# %%
# import library
library(ggplot2)
# Out:
# Registered S3 methods overwritten by 'ggplot2':
#   method         from
#   [.quosures     rlang
#   c.quosures     rlang
#   print.quosures rlang

# %%
head(train)
# Out:
#   date_time           site_name posa_continent user_location_country
# 1 2014-08-11 07:46:59 2         3              66
# 2 2014-08-11 08:22:12 2         3              66
# 3 2014-08-11 08:24:33 2         3              66
# 4 2014-08-09 18:05:16 2         3              66
# 5 2014-08-09 18:08:18 2         3              66
# 6 2014-08-09 18:13:12 2         3              66
#   user_location_region user_location_city orig_destination_distance user_id
# 1 348                  48862              2234.2641                 12
# 2 348                  48862              2234.2641                 12
# 3 348                  48862              2234.2641                 12
# 4 442                  35390               913.1932                 93
# 5 442                  35390               913.6259                 93
# 6 442                  35390               911.5142                 93
#   is_mobile is_package ... srch_children_cnt srch_rm_cnt srch_destination_id
# ...

# %%
hist(train$hotel_cluster,col="blue")
# Out:
# Plot with title "Histogram of train$hotel_cluster"

# %% [markdown]
# From above histogram plot, it is clear that it has only 100 hotel clusters in the given dataset.

# %%
## Box plot to explore attendance by day of week
boxplot(train$is_booking, train$hotel_cluster , main = "plotting booking vs hotel_cluster", xlab = "booking", ylab = "cluster", col = "green", las = 1)
# Out:
# Plot with title "plotting booking vs hotel_cluster"

# %% [markdown]
# Hence, I saw the structure of the data and aslo summary of the data. Dataset is very large and hard to handle, i have
# got some inferences form this data summary. Rest of other i will be doing on python such as EDA and Modeling.
